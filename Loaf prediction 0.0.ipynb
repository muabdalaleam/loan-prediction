# %% [markdown]
# <h2><center><strong>Describing the project

# %% [markdown]
# This is a project about classify the loaf requests so we can know it will be accepted or not the project uses this<br>
# kaggle <strong>[data set](https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset).</strong><br><br>
# The dat set contains random loaf requests from some bank the data set contains about <ins>614</ins> rows and <ins>11</ins> features<br>
# and one target the data contains an information about the person like gender and education and contains some <br>banking infromation about
# him like his co-applicant income and credit history.

# %% [markdown]
# <strong>How will we clean & augmanting the data</strong>:
# <ol>
#     <li><strong>Treating</strong> the NANs based on what's the column and what's it's count of "NANs"
#     <li><strong>Cleaning</strong> the outliers using Z-score algorithm
#     <li><strong>Scaleing</strong> the data by 2 algorithms to fit the the suitable algorithm to each ML model
#     <li><strong>Encoding</strong> the categorical features using one hot encoding
#     <li><strong>Optimizing</strong> the performance by down scaling all features
#     <li><strong>Selecting</strong> the important columns and dropping others using feature selection

# %% [markdown]
# <strong>The questions we are going to anwser</strong>:
# <ol>
#     <li>What's the general ratio of your loan request refused
#     <li>What's the the correlations between the persons bank information
#     <li>What's the the most categorical features that can affect loan status & it's effect on it
#     <li>What's the most common things in the persons banking information

# %% [markdown]
# <strong>The ML models we are going to use</strong>:
# <ul>
#     <li>Support vector machine (SVC)
#     <li>K-Neirest neighbour classifier (KNN)
#     <li>Ada boost classifier
#     <li>Logistec regression
#     <li>Random forest classifier
#     <li>Desision trees
#     <li>Simple Neural network.

# %% [markdown]
# <h2><strong><center>Data Wragling

# %% [markdown]
# <h4>1- Importing the packeges

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
from tensorflow                   import keras
from sklearn.linear_model         import LogisticRegression
from sklearn.pipeline             import Pipeline
from imblearn.over_sampling       import RandomOverSampler
from sklearn.ensemble             import AdaBoostClassifier
from sklearn.preprocessing        import MinMaxScaler
from sklearn.preprocessing        import StandardScaler
from sklearn_pandas               import DataFrameMapper
from sklearn.tree                 import DecisionTreeClassifier
from sklearn.ensemble             import RandomForestClassifier
from sklearn.neighbors            import KNeighborsClassifier
from sklearn.neighbors            import NeighborhoodComponentsAnalysis
from sklearn.model_selection      import train_test_split
from sklearn.linear_model         import SGDClassifier
from sklearn.svm                  import SVC
from sklearn.naive_bayes          import GaussianNB

rcParams["figure.figsize"] = 7, 6
plt.rcParams['axes.titlesize'] = 20
# %matplotlib inline
sns.set_style("whitegrid")

# %% [markdown]
# <h4>2- Simple describing and reading the data

# %%
base_df = pd.read_csv("Loaf dataset.csv",
                 encoding= "unicode_escape")

theme_colors = ["#ff8533", "#808080"]
font = 13
# We named the data frame base_df instead of df because we will need it again
# without any one hot encoding or scaling

# %%
base_df.sample(n= 10).style.highlight_null(null_color= theme_colors[1])
# Out:
# <style type="text/css">
# #T_b48e5_row2_col3, #T_b48e5_row4_col5, #T_b48e5_row5_col9 {
#   background-color: #808080;
# }
# </style>
# <table id="T_b48e5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Loan_ID</th>
#       <th class="col_heading level0 col1" >Gender</th>
#       <th class="col_heading level0 col2" >Married</th>
#       <th class="col_heading level0 col3" >Dependents</th>
#       <th class="col_heading level0 col4" >Education</th>
#       <th class="col_heading level0 col5" >Self_Employed</th>
#       <th class="col_heading level0 col6" >ApplicantIncome</th>
#       <th class="col_heading level0 col7" >CoapplicantIncome</th>
#       <th class="col_heading level0 col8" >LoanAmount</th>
#       <th class="col_heading level0 col9" >Loan_Amount_Term</th>
#       <th class="col_heading level0 col10" >Credit_History</th>
#       <th class="col_heading level0 col11" >Property_Area</th>
#       <th class="col_heading level0 col12" >Loan_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b48e5_level0_row0" class="row_heading level0 row0" >575</th>
#       <td id="T_b48e5_row0_col0" class="data row0 col0" >LP002868</td>
#       <td id="T_b48e5_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_b48e5_row0_col2" class="data row0 col2" >Yes</td>
#       <td id="T_b48e5_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_b48e5_row0_col4" class="data row0 col4" >Graduate</td>
#       <td id="T_b48e5_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_b48e5_row0_col6" class="data row0 col6" >3159</td>
#       <td id="T_b48e5_row0_col7" class="data row0 col7" >461.000000</td>
#       <td id="T_b48e5_row0_col8" class="data row0 col8" >108.000000</td>
#       <td id="T_b48e5_row0_col9" class="data row0 col9" >84.000000</td>
#       <td id="T_b48e5_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_b48e5_row0_col11" class="data row0 col11" >Urban</td>
#       <td id="T_b48e5_row0_col12" class="data row0 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row1" class="row_heading level0 row1" >572</th>
#       <td id="T_b48e5_row1_col0" class="data row1 col0" >LP002855</td>
#       <td id="T_b48e5_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_b48e5_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_b48e5_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_b48e5_row1_col4" class="data row1 col4" >Graduate</td>
#       <td id="T_b48e5_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_b48e5_row1_col6" class="data row1 col6" >16666</td>
#       <td id="T_b48e5_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_b48e5_row1_col8" class="data row1 col8" >275.000000</td>
#       <td id="T_b48e5_row1_col9" class="data row1 col9" >360.000000</td>
#       <td id="T_b48e5_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_b48e5_row1_col11" class="data row1 col11" >Urban</td>
#       <td id="T_b48e5_row1_col12" class="data row1 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row2" class="row_heading level0 row2" >517</th>
#       <td id="T_b48e5_row2_col0" class="data row2 col0" >LP002682</td>
#       <td id="T_b48e5_row2_col1" class="data row2 col1" >Male</td>
#       <td id="T_b48e5_row2_col2" class="data row2 col2" >Yes</td>
#       <td id="T_b48e5_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_b48e5_row2_col4" class="data row2 col4" >Not Graduate</td>
#       <td id="T_b48e5_row2_col5" class="data row2 col5" >No</td>
#       <td id="T_b48e5_row2_col6" class="data row2 col6" >3074</td>
#       <td id="T_b48e5_row2_col7" class="data row2 col7" >1800.000000</td>
#       <td id="T_b48e5_row2_col8" class="data row2 col8" >123.000000</td>
#       <td id="T_b48e5_row2_col9" class="data row2 col9" >360.000000</td>
#       <td id="T_b48e5_row2_col10" class="data row2 col10" >0.000000</td>
#       <td id="T_b48e5_row2_col11" class="data row2 col11" >Semiurban</td>
#       <td id="T_b48e5_row2_col12" class="data row2 col12" >N</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row3" class="row_heading level0 row3" >122</th>
#       <td id="T_b48e5_row3_col0" class="data row3 col0" >LP001431</td>
#       <td id="T_b48e5_row3_col1" class="data row3 col1" >Female</td>
#       <td id="T_b48e5_row3_col2" class="data row3 col2" >No</td>
#       <td id="T_b48e5_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b48e5_row3_col4" class="data row3 col4" >Graduate</td>
#       <td id="T_b48e5_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_b48e5_row3_col6" class="data row3 col6" >2137</td>
#       <td id="T_b48e5_row3_col7" class="data row3 col7" >8980.000000</td>
#       <td id="T_b48e5_row3_col8" class="data row3 col8" >137.000000</td>
#       <td id="T_b48e5_row3_col9" class="data row3 col9" >360.000000</td>
#       <td id="T_b48e5_row3_col10" class="data row3 col10" >0.000000</td>
#       <td id="T_b48e5_row3_col11" class="data row3 col11" >Semiurban</td>
#       <td id="T_b48e5_row3_col12" class="data row3 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row4" class="row_heading level0 row4" >29</th>
#       <td id="T_b48e5_row4_col0" class="data row4 col0" >LP001087</td>
#       <td id="T_b48e5_row4_col1" class="data row4 col1" >Female</td>
#       <td id="T_b48e5_row4_col2" class="data row4 col2" >No</td>
#       <td id="T_b48e5_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_b48e5_row4_col4" class="data row4 col4" >Graduate</td>
#       <td id="T_b48e5_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_b48e5_row4_col6" class="data row4 col6" >3750</td>
#       <td id="T_b48e5_row4_col7" class="data row4 col7" >2083.000000</td>
#       <td id="T_b48e5_row4_col8" class="data row4 col8" >120.000000</td>
#       <td id="T_b48e5_row4_col9" class="data row4 col9" >360.000000</td>
#       <td id="T_b48e5_row4_col10" class="data row4 col10" >1.000000</td>
#       <td id="T_b48e5_row4_col11" class="data row4 col11" >Semiurban</td>
#       <td id="T_b48e5_row4_col12" class="data row4 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row5" class="row_heading level0 row5" >165</th>
#       <td id="T_b48e5_row5_col0" class="data row5 col0" >LP001574</td>
#       <td id="T_b48e5_row5_col1" class="data row5 col1" >Male</td>
#       <td id="T_b48e5_row5_col2" class="data row5 col2" >Yes</td>
#       <td id="T_b48e5_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_b48e5_row5_col4" class="data row5 col4" >Graduate</td>
#       <td id="T_b48e5_row5_col5" class="data row5 col5" >No</td>
#       <td id="T_b48e5_row5_col6" class="data row5 col6" >3707</td>
#       <td id="T_b48e5_row5_col7" class="data row5 col7" >3166.000000</td>
#       <td id="T_b48e5_row5_col8" class="data row5 col8" >182.000000</td>
#       <td id="T_b48e5_row5_col9" class="data row5 col9" >nan</td>
#       <td id="T_b48e5_row5_col10" class="data row5 col10" >1.000000</td>
#       <td id="T_b48e5_row5_col11" class="data row5 col11" >Rural</td>
#       <td id="T_b48e5_row5_col12" class="data row5 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_b48e5_level0_row6" class="row_heading level0 row6" >413</th>
#       <td id="T_b48e5_row6_col0" class="data row6 col0" >LP002332</td>
#       <td id="T_b48e5_row6_col1" class="data row6 col1" >Male</td>
#       <td id="T_b48e5_row6_col2" class="data row6 col2" >Yes</td>
#       <td id="T_b48e5_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_b48e5_row6_col4" class="data row6 col4" >Not Graduate</td>
#       <td id="T_b48e5_row6_col5" class="data row6 col5" >No</td>
#       <td id="T_b48e5_row6_col6" class="data row6 col6" >2253</td>
#       <td id="T_b48e5_row6_col7" class="data row6 col7" >2033.000000</td>
#       <td id="T_b48e5_row6_col8" class="data row6 col8" >110.000000</td>
#       <td id="T_b48e5_row6_col9" class="data row6 col9" >360.000000</td>
#       <td id="T_b48e5_row6_col10" class="data row6 col10" >1.000000</td>
#       <td id="T_b48e5_row6_col11" class="data row6 col11" >Rural</td>
#       <td id="T_b48e5_row6_col12" class="data row6 col12" >Y</

# %%
cm = sns.light_palette(theme_colors[0], as_cmap=True)
base_df.head().style.text_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_46d95_row0_col6 {
#   color: #fe8a3b;
# }
# #T_46d95_row0_col7, #T_46d95_row0_col9, #T_46d95_row0_col10, #T_46d95_row1_col9, #T_46d95_row1_col10, #T_46d95_row2_col7, #T_46d95_row2_col8, #T_46d95_row2_col9, #T_46d95_row2_col10, #T_46d95_row3_col6, #T_46d95_row3_col9, #T_46d95_row3_col10, #T_46d95_row4_col7, #T_46d95_row4_col9, #T_46d95_row4_col10 {
#   color: #f3f0ef;
# }
# #T_46d95_row0_col8 {
#   color: #000000;
# }
# #T_46d95_row1_col6 {
#   color: #fab181;
# }
# #T_46d95_row1_col7 {
#   color: #fbac77;
# }
# #T_46d95_row1_col8 {
#   color: #fd9753;
# }
# #T_46d95_row2_col6 {
#   color: #f4e3d8;
# }
# #T_46d95_row3_col7, #T_46d95_row4_col6, #T_46d95_row4_col8 {
#   color: #ff8533;
# }
# #T_46d95_row3_col8 {
#   color: #fca367;
# }
# </style>
# <table id="T_46d95_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Loan_ID</th>
#       <th class="col_heading level0 col1" >Gender</th>
#       <th class="col_heading level0 col2" >Married</th>
#       <th class="col_heading level0 col3" >Dependents</th>
#       <th class="col_heading level0 col4" >Education</th>
#       <th class="col_heading level0 col5" >Self_Employed</th>
#       <th class="col_heading level0 col6" >ApplicantIncome</th>
#       <th class="col_heading level0 col7" >CoapplicantIncome</th>
#       <th class="col_heading level0 col8" >LoanAmount</th>
#       <th class="col_heading level0 col9" >Loan_Amount_Term</th>
#       <th class="col_heading level0 col10" >Credit_History</th>
#       <th class="col_heading level0 col11" >Property_Area</th>
#       <th class="col_heading level0 col12" >Loan_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46d95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46d95_row0_col0" class="data row0 col0" >LP001002</td>
#       <td id="T_46d95_row0_col1" class="data row0 col1" >Male</td>
#       <td id="T_46d95_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_46d95_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_46d95_row0_col4" class="data row0 col4" >Graduate</td>
#       <td id="T_46d95_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_46d95_row0_col6" class="data row0 col6" >5849</td>
#       <td id="T_46d95_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_46d95_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_46d95_row0_col9" class="data row0 col9" >360.000000</td>
#       <td id="T_46d95_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_46d95_row0_col11" class="data row0 col11" >Urban</td>
#       <td id="T_46d95_row0_col12" class="data row0 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_46d95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46d95_row1_col0" class="data row1 col0" >LP001003</td>
#       <td id="T_46d95_row1_col1" class="data row1 col1" >Male</td>
#       <td id="T_46d95_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_46d95_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_46d95_row1_col4" class="data row1 col4" >Graduate</td>
#       <td id="T_46d95_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_46d95_row1_col6" class="data row1 col6" >4583</td>
#       <td id="T_46d95_row1_col7" class="data row1 col7" >1508.000000</td>
#       <td id="T_46d95_row1_col8" class="data row1 col8" >128.000000</td>
#       <td id="T_46d95_row1_col9" class="data row1 col9" >360.000000</td>
#       <td id="T_46d95_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_46d95_row1_col11" class="data row1 col11" >Rural</td>
#       <td id="T_46d95_row1_col12" class="data row1 col12" >N</td>
#     </tr>
#     <tr>
#       <th id="T_46d95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46d95_row2_col0" class="data row2 col0" >LP001005</td>
#       <td id="T_46d95_row2_col1" class="data row2 col1" >Male</td>
#       <td id="T_46d95_row2_col2" class="data row2 col2" >Yes</td>
#       <td id="T_46d95_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_46d95_row2_col4" class="data row2 col4" >Graduate</td>
#       <td id="T_46d95_row2_col5" class="data row2 col5" >Yes</td>
#       <td id="T_46d95_row2_col6" class="data row2 col6" >3000</td>
#       <td id="T_46d95_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_46d95_row2_col8" class="data row2 col8" >66.000000</td>
#       <td id="T_46d95_row2_col9" class="data row2 col9" >360.000000</td>
#       <td id="T_46d95_row2_col10" class="data row2 col10" >1.000000</td>
#       <td id="T_46d95_row2_col11" class="data row2 col11" >Urban</td>
#       <td id="T_46d95_row2_col12" class="data row2 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_46d95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46d95_row3_col0" class="data row3 col0" >LP001006</td>
#       <td id="T_46d95_row3_col1" class="data row3 col1" >Male</td>
#       <td id="T_46d95_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_46d95_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_46d95_row3_col4" class="data row3 col4" >Not Graduate</td>
#       <td id="T_46d95_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_46d95_row3_col6" class="data row3 col6" >2583</td>
#       <td id="T_46d95_row3_col7" class="data row3 col7" >2358.000000</td>
#       <td id="T_46d95_row3_col8" class="data row3 col8" >120.000000</td>
#       <td id="T_46d95_row3_col9" class="data row3 col9" >360.000000</td>
#       <td id="T_46d95_row3_col10" class="data row3 col10" >1.000000</td>
#       <td id="T_46d95_row3_col11" class="data row3 col11" >Urban</td>
#       <td id="T_46d95_row3_col12" class="data row3 col12" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_46d95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46d95_row4_col0" class="data row4 col0" >LP001008</td>
#       <td id="T_46d95_row4_col1" class="data row4 col1" >Male</td>
#       <td id="T_46d95_row4_col2" class="data row4 col2" >No</td>
#       <td id="T_46d95_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_46d95_row4_col4" class="data row4 col4" >Graduate</td>
#       <td id="T_46d95_row4_col5" class="data row4 col5" >No</td>
#       <td id="T_46d95_row4_col6" class="data row4 col6" >6000</td>
#       <td id="T_46d95_row4_col7" class="data row4 col7" >0.000000</td>
#       <td id="T_46d95_row4_col8" class="data row4 col8" >141.000000</td>
#       <td id="T_46d95_row4_col9" class="data row4 col9" >360.000000</td>
#       <td id="T_46d95_row4_col10" class="data row4 col10" >1.000000</td>
#       <td id="T_46d95_row4_col11" class="data row4 col11" >Urban</td>
#       <td id="T_46d95_row4_col12" class="data row4 col12" >Y</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Data columns info: \n")
base_df.info(verbose = True)

# There is some nulls we will visualie them in the next section
# Out:
# Data columns info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
print("Statics of numirec data: \n")

df = base_df.copy()
base_df.describe()
# Out:
# Statics of numirec data:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ApplicantIncome</th>
#       <th>CoapplicantIncome</th>
#       <th>LoanAmount</th>
#       <th>Loan_Amount_Term</th>
#       <th>Credit_History</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>614.000000</td>
#       <td>614.000000</td>
#       <td>592.000000</td>
#       <td>600.00000</td>
#       <td>564.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5403.459283</td>
#       <td>1621.245798</td>
#       <td>146.412162</td>
#       <td>342.00000</td>
#       <td>0.842199</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>6109.041673</td>
#       <td>2926.248369</td>
#       <td>85.587325</td>
#       <td>65.12041</td>
#       <td>0.364878</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>150.000000</td>
#       <td>0.000000</td>
#       <td>9.000000</td>
#       <td>12.00000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2877.500000</td>
#       <td>0.000000</td>
#       <td>100.000000</td>
#       <td>360.00000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3812.500000</td>
#       <td>1188.500000</td>
#       <td>128.000000</td>
#       <td>360.00000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>5795.000000</td>
#       <td>2297.250000</td>
#       <td>168.000000</td>
#       <td>360.00000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>81000.000000</td>
#       <td>41667.000000</td>
#       <td>700.000000</td>
#       <td>480.00000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
base_df.shape
# Out:
# (614, 13)

# %%
base_df.duplicated().any()
# Out:
# False

# %% [markdown]
# **From this section we can conclude**:
# - There is NANs in the dataframe.
# - There is no dublicated rows
# - The difference between max and min is to huge which means there is outliers

# %% [markdown]
# <h4>3- Describing the quality issues by visualization

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

sns.boxplot(x =base_df["LoanAmount"], ax = axes[1,0], color= "#b3b3ff")
sns.boxplot(x= base_df["Loan_Amount_Term"], ax = axes[1,1], color= "#b3ffd9")
sns.boxplot(x= base_df["ApplicantIncome"], ax = axes[0,0], color= "#ffcccc")
sns.boxplot(x= base_df["CoapplicantIncome"], ax = axes[0,1], color= "#e6b3ff")

fig.set_size_inches(10,6)
fig.suptitle("Box plots to describe outliers", fontsize= font)
plt.show()

# %%
fig, (ax1, ax2, ax3, ax4, ax5)  = plt.subplots(5, sharey= True)

def histogram(col_name, c, data, x_label, axes):
    
    sns.histplot(x= col_name, data= base_df, ax= axes, color= c)
    axes.set_xlabel(x_label)
    axes.set_ylabel('Count')
    
    
histogram(col_name= "Gender", c= "#ff80ff", x_label= "Gender", axes = ax1, data= base_df)
histogram(col_name= "Married", c= "#ffb366", x_label= "Married or not", axes = ax2, data= base_df)
histogram(col_name= "Education", c= "#66a3ff", x_label= "Education", axes = ax3, data= base_df)
histogram(col_name= "Self_Employed", c= "#70db70", x_label= "Self employed or not", axes = ax4, data= base_df)
histogram(col_name= "Loan_Status", c= "#ff4d4d", x_label= "Accepted loan or not", axes = ax5, data= base_df)

fig.set_size_inches(7,16)
fig.set_dpi(100)
fig.suptitle("Visualizing the balancing of the data", fontsize= font)

plt.show()

# %% [markdown]
# The data is not very balanced so we will random over sample it
# later.

# %%
fig, axes = plt.subplots(1)
null_count = []

for col in df.columns:
    null_count.append(df[col].isnull().sum())
    
axes.bar(df.columns, null_count, color= theme_colors[0])

plt.xticks(rotation= 90)
plt.ylabel("Null count")
fig.suptitle("Exploring null counts", fontsize= font)
plt.show()

# %%
df_corr = df.apply(lambda x :
    pd.factorize(x)[0]).corr(method='spearman', min_periods=1)

cm = sns.light_palette(theme_colors[1], as_cmap=True)

df_corr.style.background_gradient(cmap= cm)

# We can find from this visualization there is some categorical features
# tricks the heat map like gender and id
# Out:
# <style type="text/css">
# #T_c8b24_row0_col0, #T_c8b24_row1_col1, #T_c8b24_row2_col2, #T_c8b24_row3_col3, #T_c8b24_row4_col4, #T_c8b24_row5_col5, #T_c8b24_row6_col6, #T_c8b24_row7_col7, #T_c8b24_row8_col8, #T_c8b24_row9_col9, #T_c8b24_row10_col10, #T_c8b24_row11_col11, #T_c8b24_row12_col12 {
#   background-color: #808080;
#   color: #f1f1f1;
# }
# #T_c8b24_row0_col1, #T_c8b24_row6_col2, #T_c8b24_row8_col7, #T_c8b24_row11_col2, #T_c8b24_row12_col1 {
#   background-color: #d3d3d3;
#   color: #000000;
# }
# #T_c8b24_row0_col2, #T_c8b24_row6_col1, #T_c8b24_row7_col6 {
#   background-color: #d4d4d4;
#   color: #000000;
# }
# #T_c8b24_row0_col3, #T_c8b24_row9_col7, #T_c8b24_row11_col8 {
#   background-color: #dcdcdc;
#   color: #000000;
# }
# #T_c8b24_row0_col4, #T_c8b24_row3_col4, #T_c8b24_row7_col11, #T_c8b24_row10_col4, #T_c8b24_row10_col7 {
#   background-color: #e4e4e4;
#   color: #000000;
# }
# #T_c8b24_row0_col5, #T_c8b24_row0_col9, #T_c8b24_row1_col12, #T_c8b24_row5_col10, #T_c8b24_row5_col12, #T_c8b24_row11_col5, #T_c8b24_row12_col8 {
#   background-color: #e5e5e5;
#   color: #000000;
# }
# #T_c8b24_row0_col6 {
#   background-color: #949494;
#   color: #f1f1f1;
# }
# #T_c8b24_row0_col7 {
#   background-color: #c5c5c5;
#   color: #000000;
# }
# #T_c8b24_row0_col8 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_c8b24_row0_col10, #T_c8b24_row3_col10, #T_c8b24_row4_col5, #T_c8b24_row5_col4, #T_c8b24_row5_col9, #T_c8b24_row9_col0, #T_c8b24_row10_col8, #T_c8b24_row11_col4 {
#   background-color: #e9e9e9;
#   color: #000000;
# }
# #T_c8b24_row0_col11, #T_c8b24_row1_col11, #T_c8b24_row7_col3, #T_c8b24_row10_col3, #T_c8b24_row12_col4 {
#   background-color: #dfdfdf;
#   color: #000000;
# }
# #T_c8b24_row0_col12, #T_c8b24_row2_col8, #T_c8b24_row3_col12, #T_c8b24_row12_col5 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_c8b24_row1_col0, #T_c8b24_row2_col10, #T_c8b24_row2_col12, #T_c8b24_row9_col6 {
#   background-color: #eeeeee;
#   color: #000000;
# }
# #T_c8b24_row1_col2, #T_c8b24_row1_col3, #T_c8b24_row1_col7, #T_c8b24_row1_col9, #T_c8b24_row2_col0, #T_c8b24_row2_col1, #T_c8b24_row4_col8, #T_c8b24_row7_col5, #T_c8b24_row7_col10, #T_c8b24_row8_col4, #T_c8b24_row11_col12, #T_c8b24_row12_col0, #T_c8b24_row12_col6, #T_c8b24_row12_col11 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_c8b24_row1_col4, #T_c8b24_row4_col0, #T_c8b24_row5_col0, #T_c8b24_row8_col10, #T_c8b24_row11_col10 {
#   background-color: #ebebeb;
#   color: #000000;
# }
# #T_c8b24_row1_col5, #T_c8b24_row1_col10, #T_c8b24_row10_col6 {
#   background-color: #ededed;
#   color: #000000;
# }
# #T_c8b24_row1_col6 {
#   background-color: #f0f0f0;
#   color: #000000;
# }
# #T_c8b24_row1_col8, #T_c8b24_row2_col4, #T_c8b24_row2_col5, #T_c8b24_row2_col11, #T_c8b24_row3_col6, #T_c8b24_row3_col11, #T_c8b24_row4_col6, #T_c8b24_row4_col9, #T_c8b24_row4_col10, #T_c8b24_row4_col11, #T_c8b24_row5_col7, #T_c8b24_row9_col5, #T_c8b24_row10_col11, #T_c8b24_row11_col6, #T_c8b24_row12_col7, #T_c8b24_row12_col9 {
#   background-color: #e6e6e6;
#   color: #000000;
# }
# #T_c8b24_row2_col3 {
#   background-color: #bebebe;
#   color: #000000;
# }
# #T_c8b24_row2_col6, #T_c8b24_row7_col12, #T_c8b24_row11_col9 {
#   background-color: #efefef;
#   color: #000000;
# }
# #T_c8b24_row2_col7 {
#   background-color: #c2c2c2;
#   color: #000000;
# }
# #T_c8b24_row2_col9, #T_c8b24_row5_col8, #T_c8b24_row6_col5, #T_c8b24_row6_col12, #T_c8b24_row7_col9, #T_c8b24_row8_col5, #T_c8b24_row11_col0 {
#   background-color: #e8e8e8;
#   color: #000000;
# }
# #T_c8b24_row3_col0, #T_c8b24_row6_col10 {
#   background-color: #eaeae9;
#   color: #000000;
# }
# #T_c8b24_row3_col1, #T_c8b24_row6_col4, #T_c8b24_row11_col3 {
#   background-color: #e1e1e1;
#   color: #000000;
# }
# #T_c8b24_row3_col2 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_c8b24_row3_col5, #T_c8b24_row3_col8, #T_c8b24_row5_col11, #T_c8b24_row8_col9, #T_c8b24_row8_col12, #T_c8b24_row9_col12, #T_c8b24_row12_col3 {
#   background-color: #e2e2e2;
#   color: #000000;
# }
# #T_c8b24_row3_col7, #T_c8b24_row4_col3, #T_c8b24_row4_col12, #T_c8b24_row11_col7 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_c8b24_row3_col9, #T_c8b24_row7_col4, #T_c8b24_row9_col8 {
#   background-color: #e0e0e0;
#   color: #000000;
# }
# #T_c8b24_row4_col1, #T_c8b24_row10_col2 {
#   background-color: #d6d6d6;
#   color: #000000;
# }
# #T_c8b24_row4_col2, #T_c8b24_row8_col2 {
#   background-color: #d2d2d2;
#   color: #000000;
# }
# #T_c8b24_row4_col7, #T_c8b24_row5_col1, #T_c8b24_row9_col3 {
#   background-color: #d7d7d7;
#   color: #000000;
# }
# #T_c8b24_row5_col2, #T_c8b24_row7_col0, #T_c8b24_row8_col1, #T_c8b24_row9_col2 {
#   background-color: #d1d1d1;
#   color: #000000;
# }
# #T_c8b24_row5_col3, #T_c8b24_row7_col8, #T_c8b24_row8_col3 {
#   background-color: #dbdbdb;
#   color: #000000;
# }
# #T_c8b24_row5_col6, #T_c8b24_row10_col0 {
#   background-color: #edeeed;
#   color: #000000;
# }
# #T_c8b24_row6_col0 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_c8b24_row6_col3, #T_c8b24_row8_col11, #T_c8b24_row12_col2 {
#   background-color: #dadada;
#   color: #000000;
# }
# #T_c8b24_row6_col7, #T_c8b24_row8_col0 {
#   background-color: #c8c8c8;
#   color: #000000;
# }
# #T_c8b24_row6_col8 {
#   background-color: #c6c6c6;
#   color: #000000;
# }
# #T_c8b24_row6_col9, #T_c8b24_row9_col11 {
#   background-color: #eaeaea;
#   color: #000000;
# }
# #T_c8b24_row6_col11 {
#   background-color: #dedede;
#   color: #000000;
# }
# #T_c8b24_row7_col1, #T_c8b24_row9_col4, #T_c8b24_row10_col5 {
#   background-color: #e3e3e3;
#   color: #000000;
# }
# #T_c8b24_row7_col2 {
#   background-color: #bbbbbb;
#   color: #000000;
# }
# #T_c8b24_row8_col6 {
#   background-color: #cbcbcb;
#   color: #000000;
# }
# #T_c8b24_row9_col1 {
#   background-color: #d8d8d8;
#   color: #000000;
# }
# #T_c8b24_row9_col10, #T_c8b24_row10_col9 {
#   background-color: #ececec;
#   color: #000000;
# }
# #T_c8b24_row10_col1 {
#   background-color: #d5d5d5;
#   color: #000000;
# }
# #T_c8b24_row10_col12 {
#   background-color: #bababa;
#   color: #000000;
# }
# #T_c8b24_row11_col1 {
#   background-color: #cdcdcd;
#   color: #000000;
# }
# #T_c8b24_row12_col10 {
#   background-color: #bcbcbc;
#   color: #000000;
# }
# </style>
# <table id="T_c8b24_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Loan_ID</th>
#       <th class="col_heading level0 col1" >Gender</th>
#       <th class="col_heading level0 col2" >Married</th>
#       <th class="col_heading level0 col3" >Dependents</th>
#       <th class="col_heading level0 col4" >Education</th>
#       <th class="col_heading level0 col5" >Self_Employed</th>
#       <th class="col_heading level0 col6" >ApplicantIncome</th>
#       <th class="col_heading level0 col7" >CoapplicantIncome</th>
#       <th class="col_heading level0 col8" >LoanAmount</th>
#       <th class="col_heading level0 col9" >Loan_Amount_Term</th>
#       <th class="col_heading level0 col10" >Credit_History</th>
#       <th class="col_heading level0 col11" >Property_Area</th>
#       <th class="col_heading level0 col12" >Loan_Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b24_level0_row0" class="row_heading level0 row0" >Loan_ID</th>
#       <td id="T_c8b24_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c8b24_row0_col1" class="data row0 col1" >0.010643</td>
#       <td id="T_c8b24_row0_col2" class="data row0 col2" >-0.011915</td>
#       <td id="T_c8b24_row0_col3" class="data row0 col3" >0.051586</td>
#       <td id="T_c8b24_row0_col4" class="data row0 col4" >0.039442</td>
#       <td id="T_c8b24_row0_col5" class="data row0 col5" >0.036564</td>
#       <td id="T_c8b24_row0_col6" class="data row0 col6" >0.813295</td>
#       <td id="T_c8b24_row0_col7" class="data row0 col7" >0.268943</td>
#       <td id="T_c8b24_row0_col8" class="data row0 col8" >0.352690</td>
#       <td id="T_c8b24_row0_col9" class="data row0 col9" >0.058098</td>
#       <td id="T_c8b24_row0_col10" class="data row0 col10" >0.016315</td>
#       <td id="T_c8b24_row0_col11" class="data row0 col11" >0.066063</td>
#       <td id="T_c8b24_row0_col12" class="data row0 col12" >-0.011773</td>
#     </tr>
#     <tr>
#       <th id="T_c8b24_level0_row1" class="row_heading level0 row1" >Gender</th>
#       <td id="T_c8b24_row1_col0" cl

# %% [markdown]
# <h4>4- feature engineering

# %% [markdown]
# **treating "NAN"s**

# %%
df["Gender"] = df["Gender"].fillna("Unkown")
df["Gender"].unique()

df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 492 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            492 non-null    object
#  1   Gender             492 non-null    object
#  2   Married            492 non-null    object
#  3   Dependents         492 non-null    object
#  4   Education          492 non-null    object
#  5   Self_Employed      492 non-null    object
#  6   ApplicantIncome    492 non-null    int64
#  7   CoapplicantIncome  492 non-null    float64
#  8   LoanAmount         492 non-null    float64
#  9   Loan_Amount_Term   492 non-null    float64
#  10  Credit_History     492 non-null    float64
#  11  Property_Area      492 non-null    object
#  12  Loan_Status        492 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 53.8+ KB

# %%
df.isnull().sum()
# Out:
# <pre>Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64</pre>

# %% [markdown]
# **Simplifying data types**

# %%
# We will drop id column becuase it's useless
df = df.drop("Loan_ID", axis= 1)
df.dtypes
# Out:
# <pre>Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object</pre>

# %%
df["Dependents"] = df["Dependents"].replace({"3+" : 3})

# %%
categorical_cols = ["Married", "Gender", "Self_Employed", "Education",
                    "Loan_Status", "Property_Area"]

continous_cols = ["LoanAmount", "Loan_Amount_Term",
                  "ApplicantIncome", "CoapplicantIncome", "Credit_History"]

for col in categorical_cols:
    df[col] = df[col].astype("category")
    
for col in continous_cols:
    df[col] = df[col].astype("int16")

# %%
# We will drop id column because it's useless
df.dtypes
# Out:
# <pre>Gender               category
# Married              category
# Dependents             object
# Education            category
# Self_Employed        category
# ApplicantIncome         int16
# CoapplicantIncome       int16
# LoanAmount              int16
# Loan_Amount_Term        int16
# Credit_History          int16
# Property_Area        category
# Loan_Status          category
# dtype: object</pre>

# %% [markdown]
# **One hot encoding for categoricals**

# %%
for col in categorical_cols:
    print(f"Unique values of {col} column is : {list(df[col].unique())}")
# Out:
# Unique values of Married column is : ['Yes', 'No']
# Unique values of Gender column is : ['Male', 'Female', 'Unkown']
# Unique values of Self_Employed column is : ['No', 'Yes']
# Unique values of Education column is : ['Graduate', 'Not Graduate']
# Unique values of Loan_Status column is : ['N', 'Y']
# Unique values of Property_Area column is : ['Rural', 'Urban', 'Semiurban']

# %%
def one_hot_encode(data, cols, postfix= "_new") -> pd.DataFrame:
    
    """
    This simple function takes a data frame and
    one hot uncode it's columns.
    
    :returns:the data frame but with one hot encode it
    and replaced it's old categorical cols with new cols
    
    :params:takes the data frame and a list of the categorical 
    column names and takes a post fix to add after the new column
    defualt is : "_new"
    """
    
    global new_cols
    new_cols = [col + "_new" for col in cols]
    
    for new_col, col in zip(new_cols, cols):
        data[new_col] = data[col].cat.codes
        
    data = data.drop(cols, axis= 1)
    return data

df = one_hot_encode(df, categorical_cols)

# %%
for col in new_cols:
    print(f"Unique values for {col} column after "+ \
          f"one hot encoding is: {list(df[col].unique())}")
# Out:
# Unique values for Married_new column after one hot encoding is: [1, 0]
# Unique values for Gender_new column after one hot encoding is: [1, 0, 2]
# Unique values for Self_Employed_new column after one hot encoding is: [0, 1]
# Unique values for Education_new column after one hot encoding is: [0, 1]
# Unique values for Loan_Status_new column after one hot encoding is: [0, 1]
# Unique values for Property_Area_new column after one hot encoding is: [0, 2, 1]

# %% [markdown]
# **Outlier detection with Z-score algorithm**

# %%
def z_score(df: pd.DataFrame, col_name: str) -> pd.DataFrame:
    """
    This function uses Z-score outlier detection
    method to detect outliers and retrn them in a data frame
    
    :param: Takes a data frame and the column name
    
    :return: list of the outliers you had
    in your data frame
    """
    
    std: np.float16 = np.float16(df[col_name].std())
    mean: np.float16 = np.float16(df[col_name].mean())
    
    upper_limit = mean + (3 * std)
    lower_limit = mean - (3 * std)
    
    outliers_free = [value for value in df[col_name] if 
                  not((value > upper_limit) | (value < lower_limit))]
    

    filtered_data = df.loc[df[col_name].isin(outliers_free)]
    
    
    return filtered_data

# %%
df = z_score(df, "ApplicantIncome")
df = z_score(df, "CoapplicantIncome")

fig, axes = plt.subplots(nrows=2, ncols=2)

sns.violinplot(x =df["LoanAmount"], ax = axes[1,0], color= "#b3b3ff")
sns.violinplot(x= df["Loan_Amount_Term"], ax = axes[1,1], color= "#b3ffd9")
sns.violinplot(x= df["ApplicantIncome"], ax = axes[0,0], color= "#ffcccc")
sns.violinplot(x= df["CoapplicantIncome"], ax = axes[0,1], color= "#e6b3ff")

fig.set_size_inches(10,6)
fig.suptitle("Make sure we fixed outliers", fontsize= font)
plt.show()

# %% [markdown]
# <em><strong>In this section we finished the feature engineering & cleaning step<br>
#     we will feature select & augment the data in the first sections of EDA

# %% [markdown]
# <h2><center><strong>Explartory data analysis (EDA) & Preposessing

# %%
fig, axes = plt.subplots(nrows= 1, ncols= 2)
colors = {1.0: theme_colors[0], 0.0: theme_colors[1]}

sns.scatterplot(x= "ApplicantIncome", y= "CoapplicantIncome",
                hue= "Loan_Status_new", data= df, ax = axes[1],
                hue_order= [1.0, 0.0], palette=colors, s=70)

sns.scatterplot(x= "LoanAmount", y= "ApplicantIncome",
                hue= "Loan_Status_new", data= df,
                ax = axes[0], palette=colors,
                hue_order= [1.0, 0.0], s= 70)

fig.set_size_inches(10, 4)
fig.suptitle("Scatter plots to describe when the loan is accepted")
plt.show()

# %%
grid = sns.PairGrid(data= df, y_vars="Loan_Status_new",
                 x_vars=["Education_new", "Credit_History", "Gender_new", "Married_new", "Dependents"],
                 height=4, aspect=.5)

grid.map(sns.pointplot, scale=1.3, errwidth=4, color=theme_colors[0], markers= "H", join =True)
grid.fig.suptitle("point plots for categorical columns")
plt.show()

# %% [markdown]
# (Loan status):       1 is accepted and 0 is not accepted<br>
# (Property area):     rural is 0, semiurban is 1, urban is 2<br>
# (Self employed):     0 is no 1 is yes <br>
# (Education):         1 is Graduated 0 is Not graduated<br>
# (Married):           1 is Married 0 is Not married<br>
# (Gender):            1 is Female 0 is Male 2 is Unkown<br>

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 3)

sns.countplot(data= base_df, x= "Property_Area", hue= "Loan_Status",
              palette= theme_colors, ax = axes[0, 0])

sns.countplot(data= base_df, x= "Gender", hue= "Loan_Status",
              palette= theme_colors, ax = axes[0, 1])

sns.countplot(data= base_df, x= "Married", hue= "Loan_Status",
              palette= theme_colors, ax = axes[1, 1])

sns.countplot(data= base_df, x= "Education", hue= "Loan_Status",
              palette= theme_colors, ax = axes[1, 2])

sns.countplot(data= base_df, x= "Self_Employed", hue= "Loan_Status",
              palette= theme_colors, ax = axes[1, 0])

sns.countplot(data= base_df, x= "Dependents", hue= "Loan_Status",
              palette= theme_colors, ax = axes[0, 2])

fig.set_size_inches(15, 8)
fig.suptitle("Bar plot to see when the bank more likly to accept the request", fontsize= font)
plt.show()

# %%
fig, ax = plt.subplots(ncols=1, figsize=(5, 5))

spaces = (0.05, 0.05)
label_function = lambda val:  f'{val / 100 * len(df):.0f}\n{val:.0f}%'


base_df.groupby("Loan_Status").size().plot(kind= "pie", autopct=label_function,
                                           textprops={'fontsize': 20},
                                           ax=ax, colors= theme_colors, ylabel= "",
                                           shadow= True, explode= spaces)
fig.suptitle("Accepted loan or not", fontsize= font)
plt.show()

# %%
fig, axes = plt.subplots(nrows= 2, ncols= 2)

sns.histplot(data=df, x="CoapplicantIncome", ax= axes[0,1], bins= 20, color= theme_colors[0])
sns.histplot(data=df, x="ApplicantIncome", ax= axes[1,1], bins= 20, color= theme_colors[1])
sns.histplot(data=df, x="LoanAmount", ax= axes[0,0], bins= 20, color= theme_colors[0])
sns.histplot(data=df, x="Loan_Amount_Term", ax= axes[1,0], bins= 20, color= theme_colors[1])

fig.set_size_inches(10, 6)
fig.suptitle("Continues columns histogram", fontsize= font)
plt.show()

# %% [markdown]
# From this histogrm we can find that co-applicant income is<br>
# about 360 must of time so we will drop it to enchance the<br>
# performance of the ML models.

# %%
df = df.drop("Loan_Amount_Term", axis= 1)

# %% [markdown]
# <h2><strong><center>Analysis conclusions</strong></h2>

# %% [markdown]
# <ul>
#         <li> <em>The bank doesn't accept the loan request more likly if co-applicant income = 2000
#         <li> <em>There is positive correlation between the requsted loan amount and applicant income
#         <li> <em>The bank doesn't accept more likly if loan amount between 100K and 200K and applicant income = 2500
#         <li> <em>The bank more likly to accept the loan request if you are married.
#         <li> <em>You are more likly to get the loan if you are semi urban.
#         <li> <em>There is a negative relationship between count of dependents and the chance of your loan be accepted
#         <li> <em>The general ratio of getting a loan is <strong>69%</strong>
#         <li> <em>The loan request is more likely to be accepted if you are graduated

# %% [markdown]
# <h2><center><strong>Machine learning steps

# %% [markdown]
# <h4>1- Preprossesing

# %% [markdown]
# We will prepeprocess the data with 2 deffrint ways:
# <ol>
#     <li>First way we will scale the data with Min Max scaling then we will <br>
#         radnom oversample the data then normalize it using <strong>log</strong> function<br>
#         all of this preprocessing way is for neural networks.
#     <li>Secondly we will scale the data using standard scaler for classical<br>
#         ML models.

# %%
target_col: str = "Loan_Status_new"

continous_cols = ["LoanAmount", "Loan_Amount_Term",
                  "ApplicantIncome", "CoapplicantIncome"]

del continous_cols[1]

# %%
mapper = DataFrameMapper([(continous_cols, MinMaxScaler())])

y_ros = df[target_col]
X_ros = mapper.fit_transform(df.copy(), len(continous_cols))
X_ros = pd.DataFrame(X_ros, index=df.index, columns=continous_cols)
X_ros = X_ros.join(df[df.columns.difference(X_ros.columns)]).drop(target_col, axis =1)

# %%
print(f"Shape of features before random oversampling: {X_ros.shape}")
X_ros, y_ros = RandomOverSampler().fit_resample(X_ros, y_ros)

print(f"Shape of features after random oversampling: {X_ros.shape}\n")
print(f"is there any nulls after the ROS: \n{X_ros.isnull().sum()}")
# Out:
# Shape of features before random oversampling: (478, 10)
# Shape of features after random oversampling: (664, 10)
#
# is there any nulls after the ROS:
# LoanAmount           0
# ApplicantIncome      0
# CoapplicantIncome    0
# Credit_History       0
# Dependents           0
# Education_new        0
# Gender_new           0
# Married_new          0
# Property_Area_new    0
# Self_Employed_new    0
# dtype: int64

# %%
X = pd.DataFrame(StandardScaler().fit_transform(df[continous_cols].values),
                 index= df.index, columns= continous_cols)

X = X.join(df[df.columns.difference(X.columns)]).drop(target_col, axis =1)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 613
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LoanAmount         478 non-null    float64
#  1   ApplicantIncome    478 non-null    float64
#  2   CoapplicantIncome  478 non-null    float64
#  3   Credit_History     478 non-null    int16
#  4   Dependents         478 non-null    object
#  5   Education_new      478 non-null    int8
#  6   Gender_new         478 non-null    int8
#  7   Married_new        478 non-null    int8
#  8   Property_Area_new  478 non-null    int8
#  9   Self_Employed_new  478 non-null    int8
# dtypes: float64(3), int16(1), int8(5), object(1)
# memory usage: 38.1+ KB

# %%
# Converting dependents column to int8 data type:

X["Dependents"] = X["Dependents"].astype(np.int8)
X_ros["Dependents"] = X_ros["Dependents"].astype(np.int8)

# %%
y = df[target_col]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 1/5,
                                                    random_state= 432 )

# %%
print(f"Train size = {len(X_train)}")
print(f"Test size = {len(X_test)}")
# Out:
# Train size = 382
# Test size = 96

# %% [markdown]
# X_ros and y_ros is Min max scaled and random over sampeled <em>(we will explain this later)

# %% [markdown]
# Standard scaling is a process we use to make the ML training phase easier<br>
# by minimyzing the range of the data and here it's theory: $$X\sigma = 1$$ $$X\mu = 0$$

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, log_loss, accuracy_score

def model_report(y_true, y_pred):
    
    pre = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    loss = log_loss(y_true, y_pred)
    acc = accuracy_score(y_true, y_pred)
    
    print("precision: {:4f}\nrecall: {}\nf1-score: {:4f}\nloss: {:4f}\naccuracy: {:4f}".
          format(pre, rec, f1, loss, acc))

# %% [markdown]
# <h4>2- Classic machine learning models

# %%
nca = NeighborhoodComponentsAnalysis(n_components= 10)
knn = KNeighborsClassifier(n_neighbors= 25, algorithm= "kd_tree")
random_forest = RandomForestClassifier(max_depth= 3, criterion= "gini")
desision_tree = DecisionTreeClassifier(max_depth= 2, criterion= "entropy")
ada = AdaBoostClassifier()
gussian_nayive = GaussianNB()
regressior = LogisticRegression()
pipe = Pipeline([("nca", nca), ("knn", knn)])

models = {"KNN" : knn, "KNN & NCA" : pipe, "Random forest": random_forest,
          "Desision tree" : desision_tree, "Gussian nayive": gussian_nayive,
          "Logistic regressior" : regressior, "Ada Boost": ada, "SVM" : SVC(),
          "SGD classifier" : SGDClassifier()}

print("*"* 50, "Classic models performance", "*" * 50, "\n")
for mode_name, model in models.items():

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"{mode_name}: ")
    model_report(y_test, y_pred)
    print("=" * 25 + "\n")
# Out:
# ************************************************** Classic models performance **************************************************
#
# KNN:
# precision: 0.684211
# recall: 1.0
# f1-score: 0.812500
# loss: 11.263642
# accuracy: 0.687500
# =========================
#
# KNN & NCA:
# precision: 0.747126
# recall: 1.0
# f1-score: 0.855263
# loss: 8.260004
# accuracy: 0.770833
# =========================
#
# Random forest:
# precision: 0.812500
# recall: 1.0
# f1-score: 0.896552
# loss: 5.631821
# accuracy: 0.843750
# =========================
#
# Desision tree:
# precision: 0.812500
# recall: 1.0
# f1-score: 0.896552
# loss: 5.631821
# accuracy: 0.843750
# =========================
#
# Gussian nayive:
# precision: 0.812500
# recall: 1.0
# f1-score: 0.896552
# loss: 5.631821
# accuracy: 0.843750
# =========================
#
# Logistic regressior:
# precision: 0.812500
# recall: 1.0
# f1-score: 0.896552
# loss: 5.631821
# accuracy: 0.843750
# =========================
#
# Ada Boost:
# precision: 0.805556
# recall: 0.8923076923076924
# f1-score: 0.846715
# loss: 7.884549
# accuracy: 0.781250
# =========================
#
# SVM:
# precision: 0.773810
# recall: 1.0
# f1-score: 0.872483
# loss: 7.133640
# accuracy: 0.802083
# =========================
#
# SGD classifier:
# precision: 0.785714
# recall: 0.5076923076923077
# f1-score: 0.616822
# loss: 15.393644
# accuracy: 0.572917
# =========================

# %% [markdown]
# From the cell above we can find that the best three models are <em> (The score is not constant)<em><strong>:</strong>
# <ul>
#     <li>Gussian nayive
#     <li>Logistic regressior
#     <li>Desision tree
# </ul>
# so we will save those models to use later.

# %%
import pickle

pickle.dump(gussian_nayive, open("gussian_nayive.h5", "wb"))
pickle.dump(regressior, open("logistic_regressior.h5", "wb"))
pickle.dump(desision_tree, open("desision_tree.h5", "wb"))

# %% [markdown]
# <h4>3- Neural networks

# %% [markdown]
# Here we will use the random over sampled and min max scaled features to<br>
# the neural network because it needs too much of data to get us good <br>
# predictions.<br><br>
# The "Min Max scaling" is just a normalization algorithm like standard scaling<br>
# and here is the theory of it : $xnorm_i = \frac{xi.\bar{x}}{max(x)-min(x)}$

# %%
X_ros = np.asarray(X_ros).astype('float32')
y_ros = np.asarray(y_ros).astype('float32')

X = np.asarray(X).astype('float32')
y = np.asarray(y).astype('float32')

X_train, X_test, y_train, t_test = train_test_split(
    X, y, test_size= 1/5)

X_ros_train, X_ros_test, y_ros_train, t_ros_test = train_test_split(
    X_ros, y_ros, test_size= 1/5)

# %%
def plot_history(history):

    fig, (ax1, ax2) = plt.subplots(1, 2)

    ax1.plot(history.history["accuracy"], label= "Model accuracy", color= theme_colors[0])
    ax1.plot(history.history["val_accuracy"], label= "Valid accuracy", color= theme_colors[1])
    ax1.set_title("model accuracy")
    ax1.set_ylabel("accuracy")
    ax1.set_xlabel("epoch")
    # ax1.set_color_cycle(theme_colors)
    
    ax2.plot(history.history["loss"], label= "Model loss", color= theme_colors[0])
    ax2.plot(history.history["val_loss"], label= "Valid loss", color= theme_colors[1])
    ax2.set_title("model loss", )
    ax2.set_ylabel("loss")
    ax2.set_xlabel("epoch")
    # ax2.set_color_cycle(theme_colors)

    ax1.legend()
    ax2.legend()

    fig.suptitle("Model loss & accuracy", fontsize= font)
    fig.set_size_inches(12, 7)
    plt.show()

# %% [markdown]
# We will use three deffrint [**activation functions**]("https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6") for this machine learning model<br><ul>
# <li> <strong>RElu</strong>: is a simple activation function I will use for first & third network and here is it's theory:<br>$RElu(x)=max(0, x)$<br><br>
#
# <li><strong>Soft plus</strong>: is like soft RElu function and here is it's theory:<br>
# $SoftPlus(x)=log(1+e^x)$<br><br>
#
# <li><strong>Sigmoid</strong>: is a "S" shaped activation function and here is it's theory:<br>
# $Sigmoid(x)=\frac{1}{1+e^-x}$

# %%
model = keras.Sequential()

model.add(keras.layers.Dense(units= 10,
                                 activation= "relu", input_shape= (10,))) # Input layer
model.add(keras.layers.Dropout(0.1))

model.add(keras.layers.Dense(units= 16,
                                 activation= "softplus")) # Hidden layer
model.add(keras.layers.Dropout(0.2))

model.add(keras.layers.Dense(units= 16,
                                 activation= "relu")) # Hidden layer
model.add(keras.layers.Dropout(0.15))

model.add(keras.layers.Dense(units= 1,
                                 activation= "sigmoid")) # Output layer

model.compile(optimizer= keras.optimizers.Adam(0.01), 
                              loss = "mse",
                              metrics= ["accuracy"])
    
# Training the nueral network with the ROS and min max scaled data
history = model.fit(
    X_ros_train, y_ros_train,
    epochs= 200,
    validation_split=0.2,
    verbose= 0)

plot_history(history)

# %%
# Training the nueral network but this time with Standard scaled data
history = model.fit(
    X_train, y_train,
    epochs= 200,
    validation_split=0.2,
    verbose= 0)

plot_history(history)

# %% [markdown]
# We can see from this visualization that the standard scaling is<br>
# better than min max scaling and the accuracy of the neural <br>
# network is better than classical models.
